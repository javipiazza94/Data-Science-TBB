# %%
import pandas as pd

# %%
Liga = pd.read_csv('C:/Users/puent/OneDrive/Escritorio/Javi Bootcamp/Web_Scraping_CSharp/CSVs/ClasificacionLiga2023-2024.csv')

# %%
Liga.head(21)
# Out:
#     Posicion Liga Nombre Equipo  Puntos  Partidos  Victorias  Empates  \
# 0               1   Real Madrid      62        25         19        5
# 1               2        Girona      56        25         17        5
# 2               3     Barcelona      54        25         16        6
# 3               4      Atlético      51        25         16        3
# 4               5      Athletic      49        25         14        7
# 5               6   R. Sociedad      40        26         10       10
# 6               7         Betis      39        25          9       12
# 7               8      Valencia      36        25         10        6
# 8               9    Las Palmas      35        25         10        5
# 9              10        Getafe      34        25          8       10
# 10             11       Osasuna      32        25          9        5
# 11             12    Villarreal      29        26          7        8
# ...
